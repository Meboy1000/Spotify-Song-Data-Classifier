# %%
import pandas as pd

likes = pd.read_csv('./data/PNRao_SocialMedia_Post_Likes.csv')
print(likes)
likes = likes.drop("LikeID", axis=1)
print(likes)

#likes.to_parquet("Post_Likes.parquet")
# Out:
#                  LikeID  PostID  UserID            Timestamp
# 0                LIKE-1   50001    2489  2025-07-09 13:24:01
# 1                LIKE-2   50001    1450  2025-07-08 13:24:01
# 2                LIKE-3   50001    1195  2025-07-09 13:24:01
# 3                LIKE-4   50001    1470  2025-07-09 13:24:01
# 4                LIKE-5   50001    1545  2025-07-09 13:24:01
# ...                 ...     ...     ...                  ...
# 10351738  LIKE-10351739  101609    1308  2025-06-11 06:12:57
# 10351739  LIKE-10351740  101609    1257  2025-06-12 06:12:57
# 10351740  LIKE-10351741  101609    1293  2025-06-11 06:12:57
# 10351741  LIKE-10351742  101609    1295  2025-06-11 06:12:57
# 10351742  LIKE-10351743  101609    1433  2025-06-13 06:12:57
#
# [10351743 rows x 4 columns]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 5
# ...
